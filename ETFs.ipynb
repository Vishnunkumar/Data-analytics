# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('ETFs.csv')

# %%
data['treynor_ratio_3y_1'] = pd.to_numeric(data.treynor_ratio_3y, errors='coerce' )

# %%
data.shape
# Out:
# (2105, 48)

# %%
result = data.iloc[:,47:48]
result
# Out:
#       treynor_ratio_3y_1
# 0                  15.21
# 1                   5.54
# 2                   8.75
# 3                   0.00
# 4                   0.00
# 5                  10.25
# 6                   8.44
# 7                  12.93
# 8                   3.94
# 9                   4.47
# 10                  0.95
# 11                  5.77
# 12                  0.87
# 13                 -2.20
# 14                  0.01
# 15                 -1.49
# 16                 -3.54
# 17                 -3.94
# 18                  0.63
# 19                  0.00
# 20                  0.00
# 21                  0.00
# 22                 -0.10
# 23                 -8.65
# 24                  0.00
# 25                  0.31
# 26                 -7.04
# 27                  8.37
# 28                  0.00
# 29                 12.65
# ...                  ...
# 2075               20.46
# 2076                6.53
# 2077               17.34
# 2078               12.16
# 2079                0.00
# ...

# %%
data = data.iloc[:,3:47]
data.head()
# Out:
#    total_net_assets currency            legal_type  net_annual_expenses  \
# 0      2.609800e+08      USD  Exchange Traded Fund                 1.25
# 1      4.760000e+09      USD  Exchange Traded Fund                 0.70
# 2      1.019700e+08      USD  Exchange Traded Fund                 0.25
# 3      5.179000e+07      USD  Exchange Traded Fund                 0.65
# 4      1.267000e+07      USD  Exchange Traded Fund                 0.00
#
#    portfolio_stocks  portfolio_bonds  sectors_basic_materials  \
# 0             99.10             0.00                    12.69
# 1             98.73             0.00                     5.12
# 2             98.48             0.46                     5.67
# 3             99.73             0.00                     0.50
# 4             99.94             0.00                     1.29
#
#    sectors_consumer_cyclical  sectors_financial_services  sectors_real_estate  \
# ...

# %%
data.isnull().sum()
# Out:
# fund_symbol                          0
# fund_name                            0
# category                           161
# fund_family                          0
# investment                         705
# size                               705
# total_net_assets                     0
# currency                             0
# legal_type                           0
# net_annual_expenses                  2
# portfolio_stocks                     1
# portfolio_bonds                      1
# sectors_basic_materials              1
# sectors_consumer_cyclical            1
# sectors_financial_services           1
# sectors_real_estate                  1
# sectors_consumer_defensive           1
# sectors_healthcare                   1
# sectors_utilities                    1
# sectors_communication_services       1
# sectors_energy                       1
# sectors_industrials                  1
# sectors_technology                   1
# price_earning                        1
# ...

# %%
data.dtypes
# Out:
# fund_symbol                        object
# fund_name                          object
# category                           object
# fund_family                        object
# investment                        float64
# size                              float64
# total_net_assets                  float64
# currency                           object
# legal_type                          int64
# net_annual_expenses               float64
# portfolio_stocks                  float64
# portfolio_bonds                   float64
# sectors_basic_materials           float64
# sectors_consumer_cyclical         float64
# sectors_financial_services        float64
# sectors_real_estate               float64
# sectors_consumer_defensive        float64
# sectors_healthcare                float64
# sectors_utilities                 float64
# sectors_communication_services    float64
# sectors_energy                    float64
# sectors_industrials               float64
# ...

# %%
data = data.iloc[:,:47]
data.head()
# Out:
#    total_net_assets currency  legal_type  net_annual_expenses  \
# 0      2.609800e+08      USD           1                 1.25
# 1      4.760000e+09      USD           1                 0.70
# 2      1.019700e+08      USD           1                 0.25
# 3      5.179000e+07      USD           1                 0.65
# 4      1.267000e+07      USD           1                 0.00
#
#    portfolio_stocks  portfolio_bonds  sectors_basic_materials  \
# 0             99.10             0.00                    12.69
# 1             98.73             0.00                     5.12
# 2             98.48             0.46                     5.67
# 3             99.73             0.00                     0.50
# 4             99.94             0.00                     1.29
#
#    sectors_consumer_cyclical  sectors_financial_services  sectors_real_estate  \
# 0                      12.18                       10.07                 0.00
# ...
