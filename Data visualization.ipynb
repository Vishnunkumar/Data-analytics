# %% [markdown]
# # DATA VISUALIZATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sl
import requests
from bs4 import BeautifulSoup as BS

# %%
data = pd.read_csv('TrainB.csv')
data.columns
data.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 0         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 0         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP  Outlet_Establishment_Year  Outlet_Size  \
# 0                  Dairy  249.8092                       1999          2.0
# 1            Soft Drinks   48.2692                       2009          2.0
# 2                   Meat  141.6180                       1999          2.0
# 3  Fruits and Vegetables  182.0950                       1998          NaN
# 4              Household   53.8614                       1987          3.0
#
#    Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
print(data.isnull().sum())
data.head()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 0         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 0         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP  Outlet_Establishment_Year  Outlet_Size  \
# 0                  Dairy  249.8092                       1999          2.0
# ...

# %%
plt.figure(figsize=(10,10),facecolor='gray')
plt.hist(data.Item_MRP, bins=9)
plt.xlabel("Item_MRP")
plt.ylabel("Frequency")
plt.title("MRP in practice")
# Out:
# Text(0.5,1,'MRP in practice')

# %%
plt.figure(figsize=(10,10))
plt.scatter(data.Item_MRP, data.Item_Outlet_Sales,c='g',marker='+',cmap='gray')
z =np.polyfit(data.Item_MRP, data.Item_Outlet_Sales, deg=3)

# %%
z
# Out:
# array([-1.02535786e-04,  4.17898900e-02,  1.07352789e+01,  1.33616425e+02])
