# %%
import pandas as pd

# %%
data = pd.read_csv("Monthwise.csv")

# %%
data.head()
# Out:
#                             Name                     University/College  \
# 0               Himanshu Shekhar             R. L. S. Y. College Ranchi
# 1                   Loganathan A             St.Joseph's College,Trichy
# 2                        Avinash                                  Snist
# 3                Vempati Abhiram        Vellore institute of technology
# 4  GUNTUR VENKATA SIVA SAI KUMAR  Sri MITTAPALLI college of engineering
#
#   Year of study Stream of study  \
# 0       Passout      BCA/BSC CS
# 1       Passout        BE - CSE
# 2       Passout        BE - CSE
# 3       Passout        BE - CSE
# 4       Passout      BE - E.C.E
#
#                      What have you worked on so far?  Teams  \
# 0  Javascript, Java, DBMS, Linux OS, software pac...    NaN
# 1                                               Java    NaN
# 2  Javascript, Python, CSS, Android, Java, DBMS, ...    NaN
# 3                   None, want to learn from scratch    NaN
# ...

# %%
#Available on all months
data[(data.June == 'Available') & (data.July == 'Available') & (data.August == 'Available') & (data.Sept == 'Available') &(data.Nov == 'Available') & (data.Oct == 'Available') & (data.Dec == 'Available')]
# Out:
#                     Name                           University/College  \
# 2                Avinash                                        Snist
# 5        Kushagra Sharma                              KIIT University
# 11                  Noel                               NTU, Singapore
# 12       Tejasree Boyina  Pydah college of engineering and technology
# 86      Santhosh Kumar N                          Karpagam University
# 87        Manjeet phogat       Lovely Professional University, punjab
# 89                 Anant                              bits edu campus
# 90         SAHIL JAYSWAL     sankalchand patel college of engineering
# 91         SHAKTI PRATAP                               CCS University
# 297                Rajan                                        Ignou
# 360  Kirupaa Thanani M S   Mepco Schlenk Engineering College,Sivakasi
#
#     Year of study Stream of study  \
# 2         Passout        BE - CSE
# 5        4th year        BE - CSE
# ...

# %%
#Available on all months but not necessarily on December
data[(data.June == 'Available') & (data.July == 'Available') & (data.August == 'Available') & (data.Sept == 'Available') &(data.Nov == 'Available') & (data.Oct == 'Available') | (data.Dec == 'Available')]
# Out:
#                      Name                                University/College  \
# 2                 Avinash                                             Snist
# 5         Kushagra Sharma                                   KIIT University
# 6             Karan Kachi                                 Mumbai University
# 7               CHANDRU P    Government college of Technology,coimbatore-13
# 8           VALLIYAMMAI A                                           College
# 9         Adarsh Bhardwaj                      suresh gyan vihar university
# 10          Tushar Bajpai                                               Srm
# 11                   Noel                                    NTU, Singapore
# 12        Tejasree Boyina       Pydah college of engineering and technology
# 13                Suganth  Hindusthan college of engineering and technology
# 14   Anshul Saraswat Kaul    Thapar Institute of Engineering and Technology
# ...

# %%
#Available on all months but not necessarily on December and Nov
data[(data.June == 'Available') & (data.July == 'Available') & (data.August == 'Available') & (data.Sept == 'Available') &(data.Nov == 'Available') | (data.Oct == 'Available') | (data.Dec == 'Available')]
# Out:
#                      Name                                University/College  \
# 0        Himanshu Shekhar                        R. L. S. Y. College Ranchi
# 1            Loganathan A                        St.Joseph's College,Trichy
# 2                 Avinash                                             Snist
# 3         Vempati Abhiram                   Vellore institute of technology
# 5         Kushagra Sharma                                   KIIT University
# 6             Karan Kachi                                 Mumbai University
# 7               CHANDRU P    Government college of Technology,coimbatore-13
# 8           VALLIYAMMAI A                                           College
# 9         Adarsh Bhardwaj                      suresh gyan vihar university
# 10          Tushar Bajpai                                               Srm
# 11                   Noel                                    NTU, Singapore
# ...

# %%
#Available on all months but not necessarily on December and Nov and Oct
data[(data.June == 'Available') & (data.July == 'Available') & (data.August == 'Available') | (data.Sept == 'Available') | (data.Nov == 'Available') | (data.Oct == 'Available') | (data.Dec == 'Available')]
# Out:
#                           Name  \
# 0             Himanshu Shekhar
# 1                 Loganathan A
# 2                      Avinash
# 3              Vempati Abhiram
# 5              Kushagra Sharma
# 6                  Karan Kachi
# 7                    CHANDRU P
# 8                VALLIYAMMAI A
# 9              Adarsh Bhardwaj
# 10               Tushar Bajpai
# 11                        Noel
# 12             Tejasree Boyina
# 13                     Suganth
# 14        Anshul Saraswat Kaul
# 15         Mahadevan narayanan
# 16           SAI CHARITH VADLA
# 17             Harshita Asnani
# 18               Sooraj Prasad
# 19               Shubham kumar
# 20                 P. Pavithra
# 21                 Bhavya Modi
# 22      Chenchunaidu maddineni
# 23              Sakshi Paliwal
# 24                Nishit Patel
# 25        DASARI CHAITANYA SAI
# 26           Pawan Singh Tomar
# 27   chandra sekharredfy medam
# 28              Nitesh Ghimire
# 29                Anusha Bojja
# ...

# %%
#Available on all months but not necessarily on December and Nov and Oct and Sept
data[(data.June == 'Available') & (data.July == 'Available') | (data.August == 'Available') | (data.Sept == 'Available') | (data.Nov == 'Available') | (data.Oct == 'Available') | (data.Dec == 'Available')]
# Out:
#                           Name  \
# 0             Himanshu Shekhar
# 1                 Loganathan A
# 2                      Avinash
# 3              Vempati Abhiram
# 5              Kushagra Sharma
# 6                  Karan Kachi
# 7                    CHANDRU P
# 8                VALLIYAMMAI A
# 9              Adarsh Bhardwaj
# 10               Tushar Bajpai
# 11                        Noel
# 12             Tejasree Boyina
# 13                     Suganth
# 14        Anshul Saraswat Kaul
# 15         Mahadevan narayanan
# 16           SAI CHARITH VADLA
# 17             Harshita Asnani
# 18               Sooraj Prasad
# 19               Shubham kumar
# 20                 P. Pavithra
# 21                 Bhavya Modi
# 22      Chenchunaidu maddineni
# 23              Sakshi Paliwal
# 24                Nishit Patel
# 25        DASARI CHAITANYA SAI
# 26           Pawan Singh Tomar
# 27   chandra sekharredfy medam
# 28              Nitesh Ghimire
# 29                Anusha Bojja
# ...

# %%
data["What do you want to work on"].describe
# Out:
# <bound method NDFrame.describe of 0      Website designing, choosing designs and design...
# 1      Website designing, choosing designs and design...
# 2      Website development, coding in html, css, boot...
# 3      Website development, coding in html, css, boot...
# 4      Survey on field, Content writing, Data collection
# 5      Image recognition, needs to be good in coding ...
# 6      Survey on field, Team coordinator, Data collec...
# 7      Website designing, choosing designs and design...
# 8      Website designing, choosing designs and design...
# 9      Website designing, choosing designs and design...
# 10     Website development, coding in html, css, boot...
# 11     Website development, coding in html, css, boot...
# 12     Website designing, choosing designs and design...
# 13     Build charts using mongodb and javascript, Web...
# 14     Build charts using mongodb and javascript, Cha...
# 15                                       Data collection
# ...

# %%
from tables import *
